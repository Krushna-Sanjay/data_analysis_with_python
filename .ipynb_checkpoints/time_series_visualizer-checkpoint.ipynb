# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('fcc-forum-pageviews.csv', index_col='date', parse_dates=True)
print(df.head())
# Out:
#             value
# date
# 2016-05-09   1201
# 2016-05-10   2329
# 2016-05-11   1716
# 2016-05-12  10539
# 2016-05-13   6933

# %%
df = df[(df['value'] >= df['value'].quantile(0.025)) & (df['value'] <= df['value'].quantile(0.975))]
df.head()
# Out:
#             value
# date
# 2016-05-19  19736
# 2016-05-26  18060
# 2016-05-27  19997
# 2016-05-28  19044
# 2016-05-29  20325

# %%
def draw_line_plot():
    plt.figure(figsize=(10,5))
    plt.plot(df.index, df['value'], color='green', linewidth='1')
    plt.title('Daily freeCodeCamp Forum Page Views 5/2016-12/2019')
    plt.xlabel('Date')
    plt.ylabel('Page Views')
    plt.grid(True)
    plt.show()


draw_line_plot()

# %%
def draw_bar_plot():
    df_bar = df.copy()
    df_bar['Month'] = df_bar.index.month
    df_bar['Year'] = df_bar.index.year

    df_grouped = df_bar.groupby(["Year", "Month"])["value"].mean().unstack()
    
    df_grouped.plot(kind='bar', figsize=(10,5), colormap='viridis')
    plt.title("Monthly Average Page Views per Year")
    plt.xlabel('Years')
    plt.ylabel('Average Page Views')
    plt.grid(True)
    plt.legend(title="Months", labels=["Jan", "Feb", "Mar", "Apr", "May", "Jun", 
                                       "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])
    plt.show()


draw_bar_plot()

# %%
def draw_box_plot():
    df_box = df.copy()
    df_box['Year'] = df_box.index.year
    df_box['Month'] = df_box.index.strftime('%b')

    fig, axes = plt.subplots(1, 2, figsize=(14,6))
    sns.boxplot(x='Year', y='value', data=df_box, ax=axes[0], palette="bright")
    axes[0].set_title("Year-wise Box Plot (Trend)")
    axes[0].set_xlabel("Year")
    axes[0].set_ylabel("Page Views")

    months_order = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", 
                    "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
    sns.boxplot(x='Month', y='value', data=df_box, ax=axes[1], order=months_order, palette='plasma')
    axes[1].set_title("Month-wise Box Plot (Trend)")
    axes[1].set_xlabel("Month")
    axes[1].set_ylabel("Page Views")
    plt.show()


draw_box_plot()
# Out:
# C:\Users\KRUSHNA\AppData\Local\Temp\ipykernel_11840\466891533.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Year', y='value', data=df_box, ax=axes[0], palette="bright")
# C:\Users\KRUSHNA\AppData\Local\Temp\ipykernel_11840\466891533.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Month', y='value', data=df_box, ax=axes[1], order=months_order, palette='plasma')
